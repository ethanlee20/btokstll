# %% [markdown]
# Training a neural network to predict $\delta C_9$

# %% [markdown]
# Setup

# %%
from pathlib import Path

import matplotlib.pyplot as plt

import torch
from torch import nn

from library.nn_training import select_device, train_and_eval
from library.datasets import Signal_Unbinned_Dataset, Bootstrapped_Signal_Unbinned_Dataset
from library.plotting import plot_loss_curves, plot_prediction_linearity

device = select_device()
# Out:
# Device:  cuda

# %% [markdown]
# Load / Generate Datasets

# %%
regenerate = True

level = "gen"
save_dir = "../../state/new_physics/data/processed"
raw_signal_dir = "../../state/new_physics/data/raw/signal"
raw_trials = {"train": range(0,5), "eval": range(5,10)}
q_squared_veto = False
std_scale = True

# set datasets #
# num_events_per_set = 42_000
# num_sets_per_label = {"train": 5, "eval": 5}

# set_datasets = {
#     "train": Bootstrapped_Signal_Unbinned_Dataset(level=level, split="train", save_dir=save_dir, feature_names=["q_squared"]), 
#     "eval": Bootstrapped_Signal_Unbinned_Dataset(level=level, split="eval", save_dir=save_dir, feature_names=["q_squared"])
# }

# if regenerate:
#     set_datasets["train"].generate(raw_trials["train"], raw_signal_dir, num_events_per_set, num_sets_per_label["train"], q_squared_veto=q_squared_veto, std_scale=std_scale)
#     set_datasets["eval"].generate(raw_trials["eval"], raw_signal_dir, num_events_per_set, num_sets_per_label["eval"], q_squared_veto=q_squared_veto, std_scale=std_scale)

# set_datasets["train"].load()
# set_datasets["eval"].load()

# event datasets #
event_datasets = {
    "train": Signal_Unbinned_Dataset(level=level, split="train", save_dir=save_dir, feature_names=["q_squared"]),
    "eval": Signal_Unbinned_Dataset(level=level, split="eval", save_dir=save_dir, feature_names=["q_squared"])
}

if regenerate:
    event_datasets["train"].generate(raw_trials["train"], raw_signal_dir, q_squared_veto=q_squared_veto, std_scale=std_scale)
    event_datasets["eval"].generate(raw_trials["eval"], raw_signal_dir, q_squared_veto=q_squared_veto, std_scale=std_scale)

event_datasets["train"].load(device)
event_datasets["eval"].load(device)
# Out:
# opened raw file: [1/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.01_1_re.pkl
# opened raw file: [2/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.01_2_re.pkl
# opened raw file: [3/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.01_3_re.pkl
# opened raw file: [4/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.01_4_re.pkl
# opened raw file: [5/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.08_1_re.pkl
# opened raw file: [6/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.08_2_re.pkl
# opened raw file: [7/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.08_3_re.pkl
# opened raw file: [8/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.08_4_re.pkl
# opened raw file: [9/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.15_1_re.pkl
# opened raw file: [10/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.15_2_re.pkl
# opened raw file: [11/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.15_3_re.pkl
# opened raw file: [12/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.15_4_re.pkl
# opened raw file: [13/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.23_1_re.pkl
# opened raw file: [14/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.23_2_re.pkl
# opened raw file: [15/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.23_3_re.pkl
# opened raw file: [16/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.23_4_re.pkl
# opened raw file: [17/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.38_1_re.pkl
# opened raw file: [18/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.38_2_re.pkl
# opened raw file: [19/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.38_3_re.pkl
# opened raw file: [20/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.38_4_re.pkl
# opened raw file: [21/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.3_1_re.pkl
# opened raw file: [22/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.3_2_re.pkl
# opened raw file: [23/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.3_3_re.pkl
# opened raw file: [24/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.3_4_re.pkl
# opened raw file: [25/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.45_1_re.pkl
# opened raw file: [26/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.45_2_re.pkl
# opened raw file: [27/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.45_3_re.pkl
# opened raw file: [28/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.45_4_re.pkl
# opened raw file: [29/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.52_1_re.pkl
# opened raw file: [30/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.52_2_re.pkl
# opened raw file: [31/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.52_3_re.pkl
# opened raw file: [32/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.52_4_re.pkl
# opened raw file: [33/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.67_1_re.pkl
# opened raw file: [34/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.67_2_re.pkl
# opened raw file: [35/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.67_3_re.pkl
# opened raw file: [36/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.67_4_re.pkl
# opened raw file: [37/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.6_1_re.pkl
# opened raw file: [38/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.6_2_re.pkl
# opened raw file: [39/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.6_3_re.pkl
# opened raw file: [40/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.6_4_re.pkl
# opened raw file: [41/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.75_1_re.pkl
# opened raw file: [42/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.75_2_re.pkl
# opened raw file: [43/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.75_3_re.pkl
# opened raw file: [44/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.75_4_re.pkl
# opened raw file: [45/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.82_1_re.pkl
# opened raw file: [46/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.82_2_re.pkl
# opened raw file: [47/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.82_3_re.pkl
# opened raw file: [48/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.82_4_re.pkl
# opened raw file: [49/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.89_1_re.pkl
# opened raw file: [50/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.89_2_re.pkl
# opened raw file: [51/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.89_3_re.pkl
# opened raw file: [52/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.89_4_re.pkl
# opened raw file: [53/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.97_1_re.pkl
# opened raw file: [54/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.97_2_re.pkl
# opened raw file: [55/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.97_3_re.pkl
# opened raw file: [56/175] ..\..\state\new_physics\data\raw\signal\dc9_-0.97_4_re.pkl
# opened raw file: [57/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.04_1_re.pkl
# opened raw file: [58/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.04_2_re.pkl
# opened raw file: [59/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.04_3_re.pkl
# opened raw file: [60/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.04_4_re.pkl
# opened raw file: [61/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.11_1_re.pkl
# opened raw file: [62/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.11_2_re.pkl
# opened raw file: [63/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.11_3_re.pkl
# opened raw file: [64/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.11_4_re.pkl
# opened raw file: [65/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.19_1_re.pkl
# opened raw file: [66/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.19_2_re.pkl
# opened raw file: [67/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.19_3_re.pkl
# opened raw file: [68/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.19_4_re.pkl
# opened raw file: [69/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.26_1_re.pkl
# opened raw file: [70/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.26_2_re.pkl
# opened raw file: [71/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.26_3_re.pkl
# opened raw file: [72/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.26_4_re.pkl
# opened raw file: [73/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.34_1_re.pkl
# opened raw file: [74/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.34_2_re.pkl
# opened raw file: [75/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.34_4_re.pkl
# opened raw file: [76/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.41_1_re.pkl
# opened raw file: [77/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.41_2_re.pkl
# opened raw file: [78/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.41_3_re.pkl
# opened raw file: [79/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.41_4_re.pkl
# opened raw file: [80/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.48_1_re.pkl
# opened raw file: [81/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.48_2_re.pkl
# opened raw file: [82/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.48_3_re.pkl
# opened raw file: [83/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.48_4_re.pkl
# opened raw file: [84/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.56_1_re.pkl
# opened raw file: [85/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.56_2_re.pkl
# opened raw file: [86/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.56_3_re.pkl
# opened raw file: [87/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.56_4_re.pkl
# opened raw file: [88/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.63_1_re.pkl
# opened raw file: [89/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.63_2_re.pkl
# opened raw file: [90/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.63_3_re.pkl
# opened raw file: [91/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.63_4_re.pkl
# opened raw file: [92/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.78_1_re.pkl
# opened raw file: [93/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.78_2_re.pkl
# opened raw file: [94/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.78_3_re.pkl
# opened raw file: [95/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.78_4_re.pkl
# opened raw file: [96/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.7_1_re.pkl
# opened raw file: [97/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.7_2_re.pkl
# opened raw file: [98/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.7_3_re.pkl
# opened raw file: [99/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.7_4_re.pkl
# opened raw file: [100/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.85_1_re.pkl
# opened raw file: [101/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.85_2_re.pkl
# opened raw file: [102/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.85_3_re.pkl
# opened raw file: [103/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.85_4_re.pkl
# opened raw file: [104/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.93_1_re.pkl
# opened raw file: [105/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.93_2_re.pkl
# opened raw file: [106/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.93_3_re.pkl
# opened raw file: [107/175] ..\..\state\new_physics\data\raw\signal\dc9_-1.93_4_re.pkl
# opened raw file: [108/175] ..\..\state\new_physics\data\raw\signal\dc9_-2.0_1_re.pkl
# opened raw file: [109/175] ..\..\state\new_physics\data\raw\signal\dc9_-2.0_2_re.pkl
# opened raw file: [110/175] ..\..\state\new_physics\data\raw\signal\dc9_-2.0_3_re.pkl
# opened raw file: [111/175] ..\..\state\new_physics\data\raw\signal\dc9_-2.0_4_re.pkl
# opened raw file: [112/175] ..\..\state\new_physics\data\raw\signal\dc9_0.07_1_re.pkl
# opened raw file: [113/175] ..\..\state\new_physics\data\raw\signal\dc9_0.07_2_re.pkl
# opened raw file: [114/175] ..\..\state\new_physics\data\raw\signal\dc9_0.07_3_re.pkl
# opened raw file: [115/175] ..\..\state\new_physics\data\raw\signal\dc9_0.07_4_re.pkl
# opened raw file: [116/175] ..\..\state\new_physics\data\raw\signal\dc9_0.0_1_re.pkl
# opened raw file: [117/175] ..\..\state\new_physics\data\raw\signal\dc9_0.0_2_re.pkl
# opened raw file: [118/175] ..\..\state\new_physics\data\raw\signal\dc9_0.0_3_re.pkl
# opened raw file: [119/175] ..\..\state\new_physics\data\raw\signal\dc9_0.0_4_re.pkl
# opened raw file: [120/175] ..\..\state\new_physics\data\raw\signal\dc9_0.14_1_re.pkl
# opened raw file: [121/175] ..\..\state\new_physics\data\raw\signal\dc9_0.14_2_re.pkl
# opened raw file: [122/175] ..\..\state\new_physics\data\raw\signal\dc9_0.14_3_re.pkl
# opened raw file: [123/175] ..\..\state\new_physics\data\raw\signal\dc9_0.14_4_re.pkl
# opened raw file: [124/175] ..\..\state\new_physics\data\raw\signal\dc9_0.21_1_re.pkl
# opened raw file: [125/175] ..\..\state\new_physics\data\raw\signal\dc9_0.21_2_re.pkl
# opened raw file: [126/175] ..\..\state\new_physics\data\raw\signal\dc9_0.21_3_re.pkl
# opened raw file: [127/175] ..\..\state\new_physics\data\raw\signal\dc9_0.21_4_re.pkl
# opened raw file: [128/175] ..\..\state\new_physics\data\raw\signal\dc9_0.29_1_re.pkl
# opened raw file: [129/175] ..\..\state\new_physics\data\raw\signal\dc9_0.29_2_re.pkl
# opened raw file: [130/175] ..\..\state\new_physics\data\raw\signal\dc9_0.29_3_re.pkl
# opened raw file: [131/175] ..\..\state\new_physics\data\raw\signal\dc9_0.29_4_re.pkl
# opened raw file: [132/175] ..\..\state\new_physics\data\raw\signal\dc9_0.36_1_re.pkl
# opened raw file: [133/175] ..\..\state\new_physics\data\raw\signal\dc9_0.36_2_re.pkl
# opened raw file: [134/175] ..\..\state\new_physics\data\raw\signal\dc9_0.36_3_re.pkl
# opened raw file: [135/175] ..\..\state\new_physics\data\raw\signal\dc9_0.36_4_re.pkl
# opened raw file: [136/175] ..\..\state\new_physics\data\raw\signal\dc9_0.44_1_re.pkl
# opened raw file: [137/175] ..\..\state\new_physics\data\raw\signal\dc9_0.44_2_re.pkl
# opened raw file: [138/175] ..\..\state\new_physics\data\raw\signal\dc9_0.44_3_re.pkl
# opened raw file: [139/175] ..\..\state\new_physics\data\raw\signal\dc9_0.44_4_re.pkl
# opened raw file: [140/175] ..\..\state\new_physics\data\raw\signal\dc9_0.51_1_re.pkl
# opened raw file: [141/175] ..\..\state\new_physics\data\raw\signal\dc9_0.51_2_re.pkl
# opened raw file: [142/175] ..\..\state\new_physics\data\raw\signal\dc9_0.51_3_re.pkl
# opened raw file: [143/175] ..\..\state\new_physics\data\raw\signal\dc9_0.51_4_re.pkl
# opened raw file: [144/175] ..\..\state\new_physics\data\raw\signal\dc9_0.58_1_re.pkl
# opened raw file: [145/175] ..\..\state\new_physics\data\raw\signal\dc9_0.58_2_re.pkl
# opened raw file: [146/175] ..\..\state\new_physics\data\raw\signal\dc9_0.58_3_re.pkl
# opened raw file: [147/175] ..\..\state\new_physics\data\raw\signal\dc9_0.58_4_re.pkl
# opened raw file: [148/175] ..\..\state\new_physics\data\raw\signal\dc9_0.66_1_re.pkl
# opened raw file: [149/175] ..\..\state\new_physics\data\raw\signal\dc9_0.66_2_re.pkl
# opened raw file: [150/175] ..\..\state\new_physics\data\raw\signal\dc9_0.66_3_re.pkl
# opened raw file: [151/175] ..\..\state\new_physics\data\raw\signal\dc9_0.66_4_re.pkl
# opened raw file: [152/175] ..\..\state\new_physics\data\raw\signal\dc9_0.73_1_re.pkl
# opened raw file: [153/175] ..\..\state\new_physics\data\raw\signal\dc9_0.73_2_re.pkl
# opened raw file: [154/175] ..\..\state\new_physics\data\raw\signal\dc9_0.73_3_re.pkl
# opened raw file: [155/175] ..\..\state\new_physics\data\raw\signal\dc9_0.73_4_re.pkl
# opened raw file: [156/175] ..\..\state\new_physics\data\raw\signal\dc9_0.88_1_re.pkl
# opened raw file: [157/175] ..\..\state\new_physics\data\raw\signal\dc9_0.88_2_re.pkl
# opened raw file: [158/175] ..\..\state\new_physics\data\raw\signal\dc9_0.88_3_re.pkl
# opened raw file: [159/175] ..\..\state\new_physics\data\raw\signal\dc9_0.88_4_re.pkl
# opened raw file: [160/175] ..\..\state\new_physics\data\raw\signal\dc9_0.8_1_re.pkl
# opened raw file: [161/175] ..\..\state\new_physics\data\raw\signal\dc9_0.8_2_re.pkl
# opened raw file: [162/175] ..\..\state\new_physics\data\raw\signal\dc9_0.8_3_re.pkl
# opened raw file: [163/175] ..\..\state\new_physics\data\raw\signal\dc9_0.8_4_re.pkl
# opened raw file: [164/175] ..\..\state\new_physics\data\raw\signal\dc9_0.95_1_re.pkl
# opened raw file: [165/175] ..\..\state\new_physics\data\raw\signal\dc9_0.95_2_re.pkl
# opened raw file: [166/175] ..\..\state\new_physics\data\raw\signal\dc9_0.95_3_re.pkl
# opened raw file: [167/175] ..\..\state\new_physics\data\raw\signal\dc9_0.95_4_re.pkl
# opened raw file: [168/175] ..\..\state\new_physics\data\raw\signal\dc9_1.03_1_re.pkl
# opened raw file: [169/175] ..\..\state\new_physics\data\raw\signal\dc9_1.03_2_re.pkl
# opened raw file: [170/175] ..\..\state\new_physics\data\raw\signal\dc9_1.03_3_re.pkl
# opened raw file: [171/175] ..\..\state\new_physics\data\raw\signal\dc9_1.03_4_re.pkl
# opened raw file: [172/175] ..\..\state\new_physics\data\raw\signal\dc9_1.1_1_re.pkl
# opened raw file: [173/175] ..\..\state\new_physics\data\raw\signal\dc9_1.1_2_re.pkl
# opened raw file: [174/175] ..\..\state\new_physics\data\raw\signal\dc9_1.1_3_re.pkl
# opened raw file: [175/175] ..\..\state\new_physics\data\raw\signal\dc9_1.1_4_re.pkl
# opened raw file: [1/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.01_5_re.pkl
# opened raw file: [2/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.01_6_re.pkl
# opened raw file: [3/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.01_7_re.pkl
# opened raw file: [4/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.01_8_re.pkl
# opened raw file: [5/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.01_9_re.pkl
# opened raw file: [6/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.08_5_re.pkl
# opened raw file: [7/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.08_6_re.pkl
# opened raw file: [8/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.08_7_re.pkl
# opened raw file: [9/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.08_8_re.pkl
# opened raw file: [10/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.08_9_re.pkl
# opened raw file: [11/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.15_5_re.pkl
# opened raw file: [12/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.15_6_re.pkl
# opened raw file: [13/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.15_7_re.pkl
# opened raw file: [14/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.15_8_re.pkl
# opened raw file: [15/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.15_9_re.pkl
# opened raw file: [16/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.23_5_re.pkl
# opened raw file: [17/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.23_6_re.pkl
# opened raw file: [18/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.23_7_re.pkl
# opened raw file: [19/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.23_8_re.pkl
# opened raw file: [20/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.23_9_re.pkl
# opened raw file: [21/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.38_5_re.pkl
# opened raw file: [22/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.38_6_re.pkl
# opened raw file: [23/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.38_7_re.pkl
# opened raw file: [24/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.38_8_re.pkl
# opened raw file: [25/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.38_9_re.pkl
# opened raw file: [26/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.3_5_re.pkl
# opened raw file: [27/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.3_6_re.pkl
# opened raw file: [28/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.3_7_re.pkl
# opened raw file: [29/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.3_8_re.pkl
# opened raw file: [30/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.3_9_re.pkl
# opened raw file: [31/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.45_5_re.pkl
# opened raw file: [32/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.45_6_re.pkl
# opened raw file: [33/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.45_7_re.pkl
# opened raw file: [34/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.45_8_re.pkl
# opened raw file: [35/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.45_9_re.pkl
# opened raw file: [36/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.52_5_re.pkl
# opened raw file: [37/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.52_6_re.pkl
# opened raw file: [38/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.52_7_re.pkl
# opened raw file: [39/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.52_8_re.pkl
# opened raw file: [40/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.52_9_re.pkl
# opened raw file: [41/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.67_5_re.pkl
# opened raw file: [42/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.67_6_re.pkl
# opened raw file: [43/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.67_7_re.pkl
# opened raw file: [44/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.67_8_re.pkl
# opened raw file: [45/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.67_9_re.pkl
# opened raw file: [46/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.6_5_re.pkl
# opened raw file: [47/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.6_6_re.pkl
# opened raw file: [48/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.6_7_re.pkl
# opened raw file: [49/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.6_8_re.pkl
# opened raw file: [50/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.6_9_re.pkl
# opened raw file: [51/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.75_5_re.pkl
# opened raw file: [52/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.75_6_re.pkl
# opened raw file: [53/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.75_7_re.pkl
# opened raw file: [54/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.75_8_re.pkl
# opened raw file: [55/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.75_9_re.pkl
# opened raw file: [56/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.82_5_re.pkl
# opened raw file: [57/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.82_6_re.pkl
# opened raw file: [58/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.82_7_re.pkl
# opened raw file: [59/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.82_8_re.pkl
# opened raw file: [60/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.82_9_re.pkl
# opened raw file: [61/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.89_5_re.pkl
# opened raw file: [62/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.89_6_re.pkl
# opened raw file: [63/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.89_7_re.pkl
# opened raw file: [64/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.89_8_re.pkl
# opened raw file: [65/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.89_9_re.pkl
# opened raw file: [66/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.97_5_re.pkl
# opened raw file: [67/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.97_6_re.pkl
# opened raw file: [68/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.97_7_re.pkl
# opened raw file: [69/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.97_8_re.pkl
# opened raw file: [70/219] ..\..\state\new_physics\data\raw\signal\dc9_-0.97_9_re.pkl
# opened raw file: [71/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.04_5_re.pkl
# opened raw file: [72/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.04_6_re.pkl
# opened raw file: [73/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.04_7_re.pkl
# opened raw file: [74/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.04_8_re.pkl
# opened raw file: [75/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.04_9_re.pkl
# opened raw file: [76/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.11_5_re.pkl
# opened raw file: [77/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.11_6_re.pkl
# opened raw file: [78/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.11_7_re.pkl
# opened raw file: [79/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.11_8_re.pkl
# opened raw file: [80/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.11_9_re.pkl
# opened raw file: [81/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.19_5_re.pkl
# opened raw file: [82/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.19_7_re.pkl
# opened raw file: [83/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.19_8_re.pkl
# opened raw file: [84/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.19_9_re.pkl
# opened raw file: [85/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.26_5_re.pkl
# opened raw file: [86/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.26_6_re.pkl
# opened raw file: [87/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.26_7_re.pkl
# opened raw file: [88/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.26_8_re.pkl
# opened raw file: [89/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.26_9_re.pkl
# opened raw file: [90/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.34_5_re.pkl
# opened raw file: [91/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.34_6_re.pkl
# opened raw file: [92/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.34_7_re.pkl
# opened raw file: [93/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.34_8_re.pkl
# opened raw file: [94/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.34_9_re.pkl
# opened raw file: [95/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.41_5_re.pkl
# opened raw file: [96/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.41_6_re.pkl
# opened raw file: [97/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.41_7_re.pkl
# opened raw file: [98/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.41_8_re.pkl
# opened raw file: [99/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.41_9_re.pkl
# opened raw file: [100/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.48_5_re.pkl
# opened raw file: [101/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.48_6_re.pkl
# opened raw file: [102/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.48_7_re.pkl
# opened raw file: [103/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.48_8_re.pkl
# opened raw file: [104/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.48_9_re.pkl
# opened raw file: [105/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.56_5_re.pkl
# opened raw file: [106/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.56_6_re.pkl
# opened raw file: [107/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.56_7_re.pkl
# opened raw file: [108/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.56_8_re.pkl
# opened raw file: [109/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.56_9_re.pkl
# opened raw file: [110/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.63_5_re.pkl
# opened raw file: [111/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.63_6_re.pkl
# opened raw file: [112/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.63_7_re.pkl
# opened raw file: [113/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.63_8_re.pkl
# opened raw file: [114/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.63_9_re.pkl
# opened raw file: [115/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.78_5_re.pkl
# opened raw file: [116/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.78_6_re.pkl
# opened raw file: [117/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.78_7_re.pkl
# opened raw file: [118/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.78_8_re.pkl
# opened raw file: [119/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.78_9_re.pkl
# opened raw file: [120/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.7_5_re.pkl
# opened raw file: [121/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.7_6_re.pkl
# opened raw file: [122/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.7_7_re.pkl
# opened raw file: [123/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.7_8_re.pkl
# opened raw file: [124/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.7_9_re.pkl
# opened raw file: [125/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.85_5_re.pkl
# opened raw file: [126/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.85_6_re.pkl
# opened raw file: [127/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.85_7_re.pkl
# opened raw file: [128/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.85_8_re.pkl
# opened raw file: [129/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.85_9_re.pkl
# opened raw file: [130/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.93_5_re.pkl
# opened raw file: [131/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.93_6_re.pkl
# opened raw file: [132/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.93_7_re.pkl
# opened raw file: [133/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.93_8_re.pkl
# opened raw file: [134/219] ..\..\state\new_physics\data\raw\signal\dc9_-1.93_9_re.pkl
# opened raw file: [135/219] ..\..\state\new_physics\data\raw\signal\dc9_-2.0_5_re.pkl
# opened raw file: [136/219] ..\..\state\new_physics\data\raw\signal\dc9_-2.0_6_re.pkl
# opened raw file: [137/219] ..\..\state\new_physics\data\raw\signal\dc9_-2.0_7_re.pkl
# opened raw file: [138/219] ..\..\state\new_physics\data\raw\signal\dc9_-2.0_8_re.pkl
# opened raw file: [139/219] ..\..\state\new_physics\data\raw\signal\dc9_-2.0_9_re.pkl
# opened raw file: [140/219] ..\..\state\new_physics\data\raw\signal\dc9_0.07_5_re.pkl
# opened raw file: [141/219] ..\..\state\new_physics\data\raw\signal\dc9_0.07_6_re.pkl
# opened raw file: [142/219] ..\..\state\new_physics\data\raw\signal\dc9_0.07_7_re.pkl
# opened raw file: [143/219] ..\..\state\new_physics\data\raw\signal\dc9_0.07_8_re.pkl
# opened raw file: [144/219] ..\..\state\new_physics\data\raw\signal\dc9_0.07_9_re.pkl
# opened raw file: [145/219] ..\..\state\new_physics\data\raw\signal\dc9_0.0_5_re.pkl
# opened raw file: [146/219] ..\..\state\new_physics\data\raw\signal\dc9_0.0_6_re.pkl
# opened raw file: [147/219] ..\..\state\new_physics\data\raw\signal\dc9_0.0_7_re.pkl
# opened raw file: [148/219] ..\..\state\new_physics\data\raw\signal\dc9_0.0_8_re.pkl
# opened raw file: [149/219] ..\..\state\new_physics\data\raw\signal\dc9_0.0_9_re.pkl
# opened raw file: [150/219] ..\..\state\new_physics\data\raw\signal\dc9_0.14_5_re.pkl
# opened raw file: [151/219] ..\..\state\new_physics\data\raw\signal\dc9_0.14_6_re.pkl
# opened raw file: [152/219] ..\..\state\new_physics\data\raw\signal\dc9_0.14_7_re.pkl
# opened raw file: [153/219] ..\..\state\new_physics\data\raw\signal\dc9_0.14_8_re.pkl
# opened raw file: [154/219] ..\..\state\new_physics\data\raw\signal\dc9_0.14_9_re.pkl
# opened raw file: [155/219] ..\..\state\new_physics\data\raw\signal\dc9_0.21_5_re.pkl
# opened raw file: [156/219] ..\..\state\new_physics\data\raw\signal\dc9_0.21_6_re.pkl
# opened raw file: [157/219] ..\..\state\new_physics\data\raw\signal\dc9_0.21_7_re.pkl
# opened raw file: [158/219] ..\..\state\new_physics\data\raw\signal\dc9_0.21_8_re.pkl
# opened raw file: [159/219] ..\..\state\new_physics\data\raw\signal\dc9_0.21_9_re.pkl
# opened raw file: [160/219] ..\..\state\new_physics\data\raw\signal\dc9_0.29_5_re.pkl
# opened raw file: [161/219] ..\..\state\new_physics\data\raw\signal\dc9_0.29_6_re.pkl
# opened raw file: [162/219] ..\..\state\new_physics\data\raw\signal\dc9_0.29_7_re.pkl
# opened raw file: [163/219] ..\..\state\new_physics\data\raw\signal\dc9_0.29_8_re.pkl
# opened raw file: [164/219] ..\..\state\new_physics\data\raw\signal\dc9_0.29_9_re.pkl
# opened raw file: [165/219] ..\..\state\new_physics\data\raw\signal\dc9_0.36_5_re.pkl
# opened raw file: [166/219] ..\..\state\new_physics\data\raw\signal\dc9_0.36_6_re.pkl
# opened raw file: [167/219] ..\..\state\new_physics\data\raw\signal\dc9_0.36_7_re.pkl
# opened raw file: [168/219] ..\..\state\new_physics\data\raw\signal\dc9_0.36_8_re.pkl
# opened raw file: [169/219] ..\..\state\new_physics\data\raw\signal\dc9_0.36_9_re.pkl
# opened raw file: [170/219] ..\..\state\new_physics\data\raw\signal\dc9_0.44_5_re.pkl
# opened raw file: [171/219] ..\..\state\new_physics\data\raw\signal\dc9_0.44_6_re.pkl
# opened raw file: [172/219] ..\..\state\new_physics\data\raw\signal\dc9_0.44_7_re.pkl
# opened raw file: [173/219] ..\..\state\new_physics\data\raw\signal\dc9_0.44_8_re.pkl
# opened raw file: [174/219] ..\..\state\new_physics\data\raw\signal\dc9_0.44_9_re.pkl
# opened raw file: [175/219] ..\..\state\new_physics\data\raw\signal\dc9_0.51_5_re.pkl
# opened raw file: [176/219] ..\..\state\new_physics\data\raw\signal\dc9_0.51_6_re.pkl
# opened raw file: [177/219] ..\..\state\new_physics\data\raw\signal\dc9_0.51_7_re.pkl
# opened raw file: [178/219] ..\..\state\new_physics\data\raw\signal\dc9_0.51_8_re.pkl
# opened raw file: [179/219] ..\..\state\new_physics\data\raw\signal\dc9_0.51_9_re.pkl
# opened raw file: [180/219] ..\..\state\new_physics\data\raw\signal\dc9_0.58_5_re.pkl
# opened raw file: [181/219] ..\..\state\new_physics\data\raw\signal\dc9_0.58_6_re.pkl
# opened raw file: [182/219] ..\..\state\new_physics\data\raw\signal\dc9_0.58_7_re.pkl
# opened raw file: [183/219] ..\..\state\new_physics\data\raw\signal\dc9_0.58_8_re.pkl
# opened raw file: [184/219] ..\..\state\new_physics\data\raw\signal\dc9_0.58_9_re.pkl
# opened raw file: [185/219] ..\..\state\new_physics\data\raw\signal\dc9_0.66_5_re.pkl
# opened raw file: [186/219] ..\..\state\new_physics\data\raw\signal\dc9_0.66_6_re.pkl
# opened raw file: [187/219] ..\..\state\new_physics\data\raw\signal\dc9_0.66_7_re.pkl
# opened raw file: [188/219] ..\..\state\new_physics\data\raw\signal\dc9_0.66_8_re.pkl
# opened raw file: [189/219] ..\..\state\new_physics\data\raw\signal\dc9_0.66_9_re.pkl
# opened raw file: [190/219] ..\..\state\new_physics\data\raw\signal\dc9_0.73_5_re.pkl
# opened raw file: [191/219] ..\..\state\new_physics\data\raw\signal\dc9_0.73_6_re.pkl
# opened raw file: [192/219] ..\..\state\new_physics\data\raw\signal\dc9_0.73_7_re.pkl
# opened raw file: [193/219] ..\..\state\new_physics\data\raw\signal\dc9_0.73_8_re.pkl
# opened raw file: [194/219] ..\..\state\new_physics\data\raw\signal\dc9_0.73_9_re.pkl
# opened raw file: [195/219] ..\..\state\new_physics\data\raw\signal\dc9_0.88_5_re.pkl
# opened raw file: [196/219] ..\..\state\new_physics\data\raw\signal\dc9_0.88_6_re.pkl
# opened raw file: [197/219] ..\..\state\new_physics\data\raw\signal\dc9_0.88_7_re.pkl
# opened raw file: [198/219] ..\..\state\new_physics\data\raw\signal\dc9_0.88_8_re.pkl
# opened raw file: [199/219] ..\..\state\new_physics\data\raw\signal\dc9_0.88_9_re.pkl
# opened raw file: [200/219] ..\..\state\new_physics\data\raw\signal\dc9_0.8_5_re.pkl
# opened raw file: [201/219] ..\..\state\new_physics\data\raw\signal\dc9_0.8_6_re.pkl
# opened raw file: [202/219] ..\..\state\new_physics\data\raw\signal\dc9_0.8_7_re.pkl
# opened raw file: [203/219] ..\..\state\new_physics\data\raw\signal\dc9_0.8_8_re.pkl
# opened raw file: [204/219] ..\..\state\new_physics\data\raw\signal\dc9_0.8_9_re.pkl
# opened raw file: [205/219] ..\..\state\new_physics\data\raw\signal\dc9_0.95_5_re.pkl
# opened raw file: [206/219] ..\..\state\new_physics\data\raw\signal\dc9_0.95_6_re.pkl
# opened raw file: [207/219] ..\..\state\new_physics\data\raw\signal\dc9_0.95_7_re.pkl
# opened raw file: [208/219] ..\..\state\new_physics\data\raw\signal\dc9_0.95_8_re.pkl
# opened raw file: [209/219] ..\..\state\new_physics\data\raw\signal\dc9_0.95_9_re.pkl
# opened raw file: [210/219] ..\..\state\new_physics\data\raw\signal\dc9_1.03_5_re.pkl
# opened raw file: [211/219] ..\..\state\new_physics\data\raw\signal\dc9_1.03_6_re.pkl
# opened raw file: [212/219] ..\..\state\new_physics\data\raw\signal\dc9_1.03_7_re.pkl
# opened raw file: [213/219] ..\..\state\new_physics\data\raw\signal\dc9_1.03_8_re.pkl
# opened raw file: [214/219] ..\..\state\new_physics\data\raw\signal\dc9_1.03_9_re.pkl
# opened raw file: [215/219] ..\..\state\new_physics\data\raw\signal\dc9_1.1_5_re.pkl
# opened raw file: [216/219] ..\..\state\new_physics\data\raw\signal\dc9_1.1_6_re.pkl
# opened raw file: [217/219] ..\..\state\new_physics\data\raw\signal\dc9_1.1_7_re.pkl
# opened raw file: [218/219] ..\..\state\new_physics\data\raw\signal\dc9_1.1_8_re.pkl
# opened raw file: [219/219] ..\..\state\new_physics\data\raw\signal\dc9_1.1_9_re.pkl

# %%
mu = event_datasets["train"].labels.mean()
sigma = event_datasets["train"].labels.std()

event_datasets["train"].labels = (event_datasets["train"].labels - mu) / sigma
event_datasets["eval"].labels = (event_datasets["eval"].labels - mu) / sigma

# %% [markdown]
# Train / Load Model

# %% [markdown]
# Evaluate Model

# %%
class Set_Trained_Regressor_NN(nn.Module):
    """
    Neural network trained on sets (that works event-by-event?).
    """
    def __init__(self, save_dir, nickname):
        super().__init__()

        self.nickname = nickname
        self.save_path = Path(save_dir).joinpath(f"{nickname}.pt")

        self.lin = nn.Sequential(
            nn.Linear(1, 32),
            nn.ReLU(),
            nn.Linear(32, 32),
            nn.ReLU(),
            nn.Linear(32, 1),
        )
        
    def forward(self, x):
        z = self.lin(x)
        return z

retrain = True
save_dir = "../../state/new_physics/models"
nickname = "test1"
model = Set_Trained_Regressor_NN(save_dir, nickname)

if retrain:
    
    learning_rate = 1e-3
    epochs = 20
    train_batch_size = 24_000
    eval_batch_size = 24_000
    loss_fn = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    loss_table = train_and_eval(
        model, 
        event_datasets["train"], event_datasets["eval"], 
        loss_fn, 
        optimizer, 
        epochs, 
        train_batch_size, eval_batch_size, 
        device, 
        move_data=True)
    
    torch.save(model.state_dict(), model.save_path)

    _, ax = plt.subplots()
    skip_first = 2
    plot_loss_curves(loss_table["epoch"][skip_first:], loss_table["train_loss"][skip_first:], loss_table["eval_loss"][skip_first:], ax)
    plt.show()

else:
    model.load_state_dict(torch.load(model.save_path, weights_only=True))
    model.to(device)

# %%
split = "eval"

feat = event_datasets[split].features.to(device)
labels = event_datasets[split].labels.to(device)

model.eval()
with torch.no_grad():
    yhat = model(feat)

unique_labels = labels.unique()
separated_yhats = [yhat[torch.where(labels==label)] for label in unique_labels]
avgs = [i.mean() for i in separated_yhats]
stds = [i.std() for i in separated_yhats]

unique_labels = [i.cpu().numpy() for i in unique_labels]
avgs = [i.cpu().numpy() for i in avgs]
stds = [i.cpu().numpy() for i in stds]

# %%
_, ax = plt.subplots()

plot_prediction_linearity(
    ax,
    unique_labels, avgs, stds,
    ref_line_buffer=0.05,
    # xlim=(-2.25, 1.35),
    # ylim=(-2.25, 1.35),
    xlabel=r"Actual $\delta C_9$", 
    ylabel=r"Predicted $\delta C_9$"
)

# %%
plt.scatter(feat[::100].cpu(), labels[::100].cpu(), alpha=0.01)
plt.scatter(feat[::100].cpu(), yhat[::100].cpu(), alpha=0.01)

# %%
from library.datasets import Test_Linear_Dataset

test_linear_dataset = Test_Linear_Dataset()

class Test_Regressor_NN(nn.Module):
    """
    Neural network trained on sets (that works event-by-event?).
    """
    def __init__(self, save_dir, nickname):
        super().__init__()

        self.nickname = nickname
        self.save_path = Path(save_dir).joinpath(f"{nickname}.pt")

        self.lin = nn.Sequential(
            nn.Linear(1, 1),
        )
        
    def forward(self, x):
        z = self.lin(x)
        return z

retrain = True
save_dir = "../../state/new_physics/models"
nickname = "test_testlin_1"
model = Test_Regressor_NN(save_dir, nickname)

if retrain:
    
    learning_rate = 3e-2
    epochs = 75
    train_batch_size = 16
    eval_batch_size = 16
    loss_fn = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    loss_table = train_and_eval(
        model, 
        test_linear_dataset, test_linear_dataset, 
        loss_fn, 
        optimizer, 
        epochs, 
        train_batch_size, eval_batch_size, 
        device, 
        move_data=True)
    
    torch.save(model.state_dict(), model.save_path)

    _, ax = plt.subplots()
    skip_first = 2
    plot_loss_curves(loss_table["epoch"][skip_first:], loss_table["train_loss"][skip_first:], loss_table["eval_loss"][skip_first:], ax)
    plt.show()

else:
    model.load_state_dict(torch.load(model.save_path, weights_only=True))
    model.to(device)


model.eval()
with torch.no_grad():
    yhat = model(test_linear_dataset.features.to(device))

avgs = yhat.mean(dim=1)
stds = yhat.std(dim=1)

_, ax = plt.subplots()

plot_prediction_linearity(
    ax,
    test_linear_dataset.labels.squeeze().cpu().numpy(), avgs.cpu().numpy(), stds.cpu().numpy(),
    ref_line_buffer=0.05,
    # xlim=(-2.25, 1.35),
    # ylim=(-2.25, 1.35),
    xlabel=r"Actual $\delta C_9$", 
    ylabel=r"Predicted $\delta C_9$"
)
